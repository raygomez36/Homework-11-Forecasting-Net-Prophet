# %%
 # Import the required libraries and dependencies
import pandas as pd
import holoviews as hv
from prophet import Prophet
import hvplot.pandas
import datetime as dt
# %matplotlib inline
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df_mercado_trends = pd.read_csv('google_hourly_search_trends.csv').dropna()

df_mercado_trends['Date'] = pd.to_datetime(df_mercado_trends['Date'], infer_datetime_format=True, utc=True)

# Review the first five rows of the DataFrame
df_mercado_trends.head()
# Out:
# C:\Users\rayde\AppData\Local\Temp\ipykernel_12956\626516942.py:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_mercado_trends['Date'] = pd.to_datetime(df_mercado_trends['Date'], infer_datetime_format=True, utc=True)
# C:\Users\rayde\AppData\Local\Temp\ipykernel_12956\626516942.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_mercado_trends['Date'] = pd.to_datetime(df_mercado_trends['Date'], infer_datetime_format=True, utc=True)
#                        Date  Search Trends
# 0 2016-06-01 00:00:00+00:00             97
# 1 2016-06-01 01:00:00+00:00             92
# 2 2016-06-01 02:00:00+00:00             76
# ...

# %%
# Review last five rows of the DataFrame
df_mercado_trends.tail()
# Out:
#                            Date  Search Trends
# 37101 2020-09-07 20:00:00+00:00             71
# 37102 2020-09-07 21:00:00+00:00             83
# 37103 2020-09-07 22:00:00+00:00             96
# 37104 2020-09-07 23:00:00+00:00             97
# 37105 2020-09-08 00:00:00+00:00             96

# %%
df_mercado_trends['Date'] = df_mercado_trends['Date'].dt.tz_convert('US/Eastern')
df_mercado_trends.head()
# Out:
#                        Date  Search Trends
# 0 2016-05-31 20:00:00-04:00             97
# 1 2016-05-31 21:00:00-04:00             92
# 2 2016-05-31 22:00:00-04:00             76
# 3 2016-05-31 23:00:00-04:00             60
# 4 2016-06-01 00:00:00-04:00             38

# %%
# Review the data types of the DataFrame using the info function
df_mercado_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37106 entries, 0 to 37105
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           37106 non-null  datetime64[ns, US/Eastern]
#  1   Search Trends  37106 non-null  int64
# dtypes: datetime64[ns, US/Eastern](1), int64(1)
# memory usage: 579.9 KB

# %%
df_mercado_trends = df_mercado_trends.set_index('Date')

df_mercado_trends.head()
# Out:
#                            Search Trends
# Date
# 2016-05-31 20:00:00-04:00             97
# 2016-05-31 21:00:00-04:00             92
# 2016-05-31 22:00:00-04:00             76
# 2016-05-31 23:00:00-04:00             60
# 2016-06-01 00:00:00-04:00             38

# %%
# Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Slice the DataFrame to just the month of May 2020
df_may_2020 = df_mercado_trends.loc['2020-05']
df_may_2020

# Use hvPlot to visualize the data for May 2020
df_may_2020.hvplot.line()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Curve   [Date]   (Search Trends)

# %%
# Calculate the sum of the total search traffic for May 2020
traffic_may_2020 = df_may_2020['Search Trends'].groupby(by=[df_may_2020.index.day]).sum()

# View the traffic_may_2020 value
traffic_may_2020
# Out:
# Date
# 1     1107
# 2     1189
# 3     1173
# 4     1340
# 5     1527
# 6     1270
# 7     1249
# 8     1217
# 9     1161
# 10    1084
# 11    1256
# 12    1262
# 13    1270
# 14    1260
# 15    1238
# 16    1214
# 17    1201
# 18    1296
# 19    1273
# 20    1241
# 21    1253
# 22    1250
# 23    1183
# 24    1203
# 25    1213
# 26    1254
# 27    1237
# 28    1226
# 29    1200
# 30    1188
# 31    1176
# Name: Search Trends, dtype: int64

# %%
# Calcluate the monhtly median search traffic across all months 
# Group the DataFrame by index year and then index month, chain the sum and then the median functions
median_monthly_traffic = df_mercado_trends['Search Trends'].groupby(by=[df_mercado_trends.index.month]).median()

# View the median_monthly_traffic value
median_monthly_traffic
# Out:
# Date
# 1     54.0
# 2     53.0
# 3     52.0
# 4     51.0
# 5     50.0
# 6     51.0
# 7     51.0
# 8     51.0
# 9     50.0
# 10    48.0
# 11    52.0
# 12    50.0
# Name: Search Trends, dtype: float64

# %%
# Compare the seach traffic for the month of May 2020 to the overall monthly median value
traffic_may_2020/median_monthly_traffic
# Out:
# Date
# 1     20.500000
# 2     22.433962
# 3     22.557692
# 4     26.274510
# 5     30.540000
# 6     24.901961
# 7     24.490196
# 8     23.862745
# 9     23.220000
# 10    22.583333
# 11    24.153846
# 12    25.240000
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# Name: Search Trends, dtype: float64

# %%
# Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Group the hourly search data to plot (use hvPlot) the average traffic by the day of week 
traffic_may_2020_df = df_may_2020['Search Trends'].groupby(by=[df_may_2020.index.day, df_may_2020.index.hour]).median()
traffic_may_2020_df
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# Date  Date
# 1     0       53.0
#       1       33.0
#       2       19.0
#       3       12.0
#       4        8.0
#               ...
# ...

# %%
# Group the hourly search data to plot (use hvPlot) the average traffic by the day of week 
df_mercado_trends.groupby(df_mercado_trends.index.dayofweek).mean().hvplot()
# Out:
# :Curve   [Date]   (Search Trends)

# %%
 # Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Use hvPlot to visualize the hour of the day and day of week search traffic as a heatmap.
df_mercado_trends.hvplot.heatmap(x='index.hour', y='index.dayofweek', C='Search Trends', cmap='purples')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ...

# %%
# Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Group the hourly search data to plot (use hvPlot) the average traffic by the week of the year
df_mercado_trends.groupby(df_mercado_trends.index.isocalendar().week).mean().hvplot()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Curve   [week]   (Search Trends)

# %%
# Upload the "mercado_stock_price.csv" file into Colab, then store in a Pandas DataFrame
# Set the "date" column as the Datetime Index.

df_mercado_stock = pd.read_csv('mercado_stock_price.csv', index_col='date').dropna()


# View the first and last five rows of the DataFrame
# Review the first five rows of the DataFrame
df_mercado_stock.head()
# Out:
#                       close
# date
# 2015-01-02 09:00:00  127.67
# 2015-01-02 10:00:00  125.44
# 2015-01-02 11:00:00  125.57
# 2015-01-02 12:00:00  125.40
# 2015-01-02 13:00:00  125.17

# %%
# Review the Last five rows of the DataFrame
df_mercado_stock.tail()
# Out:
#                         close
# date
# 2020-07-31 11:00:00  1105.780
# 2020-07-31 12:00:00  1087.925
# 2020-07-31 13:00:00  1095.800
# 2020-07-31 14:00:00  1110.650
# 2020-07-31 15:00:00  1122.510

# %%
 # Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Use hvPlot to visualize the closing price of the df_mercado_stock DataFrame
df_mercado_stock.hvplot()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Curve   [date]   (close)

# %%
 # Concatenate the df_mercado_stock DataFrame with the df_mercado_trends DataFrame
# Concatenate the DataFrame by columns (axis=1), and drop and rows with only one column of data
mercado_stock_trends_df = pd.concat([df_mercado_stock, df_mercado_trends], axis=1)

# View the first and last five rows of the DataFrame
display(mercado_stock_trends_df.head())
display(mercado_stock_trends_df.tail())
# Out:
#                       close  Search Trends
# 2015-01-02 09:00:00  127.67            NaN
# 2015-01-02 10:00:00  125.44            NaN
# 2015-01-02 11:00:00  125.57            NaN
# 2015-01-02 12:00:00  125.40            NaN
# 2015-01-02 13:00:00  125.17            NaN
#                            close  Search Trends
# 2020-09-07 16:00:00-04:00    NaN           71.0
# 2020-09-07 17:00:00-04:00    NaN           83.0
# 2020-09-07 18:00:00-04:00    NaN           96.0
# 2020-09-07 19:00:00-04:00    NaN           97.0
# 2020-09-07 20:00:00-04:00    NaN           96.0

# %%
mercado_stock_trends_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46442 entries, 2015-01-02 09:00:00 to 2020-09-07 20:00:00-04:00
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   close          9336 non-null   float64
#  1   Search Trends  37106 non-null  float64
# dtypes: float64(2)
# memory usage: 1.1+ MB

# %%
# For the combined dataframe, slice to just the first half of 2020 (2020-01 through 2020-06) 
#mercado_stock_trends_df.reset_index()

#mercado_stock_trends_df.set_index()

first_half_2020 = mercado_stock_trends_df['2020-02':'2020-07']

# View the first and last five rows of first_half_2020 DataFrame
display(first_half_2020.head())
display(first_half_2020.tail())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-02'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 6
# ...

# %%
# Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Use hvPlot to visualize the close and Search Trends data
# Plot each column on a separate axes using the following syntax
# `hvplot(shared_axes=False, subplots=True).cols(1)`
first_half_2020.hvplot(shared_axes=False, subplots=True).cols(1)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ---------------------------------------------------------------------------
# ...

# %%
 # Create a new column in the mercado_stock_trends_df DataFrame called Lagged Search Trends
# This column should shift the Search Trends information by one hour
mercado_stock_trends_df['Lagged Search Trends'] = mercado_stock_trends_df['Search Trends'].shift(1)

# %%
 # Create a new column in the mercado_stock_trends_df DataFrame called Stock Volatility
# This column should calculate the standard deviation of the closing stock price return data over a 4 period rolling window
mercado_stock_trends_df['Stock Volatility'] = mercado_stock_trends_df['close'].pct_change().rolling(window=4).std()

# %%
# Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Use hvPlot to visualize the stock volatility
mercado_stock_trends_df['Stock Volatility'].hvplot()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ---------------------------------------------------------------------------
# ...

# %%
 # Create a new column in the mercado_stock_trends_df DataFrame called Hourly Stock Return
# This column should calculate hourly return percentage of the closing price
mercado_stock_trends_df['Hourly Stock Return'] =  mercado_stock_trends_df['close'].pct_change()

# %%
# View the first and last five rows of the mercado_stock_trends_df DataFrame
display(mercado_stock_trends_df.head())
display(mercado_stock_trends_df.tail())
# Out:
#                       close  Search Trends  Lagged Search Trends  \
# 2015-01-02 09:00:00  127.67            NaN                   NaN
# 2015-01-02 10:00:00  125.44            NaN                   NaN
# 2015-01-02 11:00:00  125.57            NaN                   NaN
# 2015-01-02 12:00:00  125.40            NaN                   NaN
# 2015-01-02 13:00:00  125.17            NaN                   NaN
#
#                      Stock Volatility  Hourly Stock Return
# 2015-01-02 09:00:00               NaN                  NaN
# 2015-01-02 10:00:00               NaN            -0.017467
# 2015-01-02 11:00:00               NaN             0.001036
# 2015-01-02 12:00:00               NaN            -0.001354
# 2015-01-02 13:00:00          0.008468            -0.001834
#                            close  Search Trends  Lagged Search Trends  \
# 2020-09-07 16:00:00-04:00    NaN           71.0                  69.0
# 2020-09-07 17:00:00-04:00    NaN           83.0                  71.0
# ...

# %%
 # Construct correlation table of Stock Volatility, Lagged Search Trends, and Hourly Stock Return
mercado_stock_trends_df[['Stock Volatility', 'Lagged Search Trends', 'Hourly Stock Return']].corr()
# Out:
#                       Stock Volatility  Lagged Search Trends  \
# Stock Volatility              1.000000              0.012502
# Lagged Search Trends          0.012502              1.000000
# Hourly Stock Return           0.062914                   NaN
#
#                       Hourly Stock Return
# Stock Volatility                 0.062914
# Lagged Search Trends                  NaN
# Hourly Stock Return              1.000000

# %%
 # Using the df_mercado_trends DataFrame, reset the index so the date information is no longer the index
mercado_prophet_df = df_mercado_trends.reset_index()

# Label the columns ds and y so that the syntax is recognized by Prophet
mercado_prophet_df.columns = ['ds', 'y']

# View the first and last five rows of the mercado_prophet_df DataFrame
display(mercado_prophet_df.head())
display(mercado_prophet_df.tail())
# Out:
#                          ds   y
# 0 2016-05-31 20:00:00-04:00  97
# 1 2016-05-31 21:00:00-04:00  92
# 2 2016-05-31 22:00:00-04:00  76
# 3 2016-05-31 23:00:00-04:00  60
# 4 2016-06-01 00:00:00-04:00  38
#                              ds   y
# 37101 2020-09-07 16:00:00-04:00  71
# 37102 2020-09-07 17:00:00-04:00  83
# 37103 2020-09-07 18:00:00-04:00  96
# 37104 2020-09-07 19:00:00-04:00  97
# 37105 2020-09-07 20:00:00-04:00  96

# %%
 # Call the Prophet function, store as an object
model_mercado_trends = Prophet()
model_mercado_trends

# %%
 # Fit the time-series model.
model_mercado_trends.fit(mercado_prophet_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 2
#       1 # Fit the time-series model.
# ----> 2 model_mercado_trends.fit(mercado_prophet_df)
#
# File ~\Anaconda3\Lib\site-packages\prophet\forecaster.py:1217, in Prophet.fit(self, df, **kwargs)
#    1213 if self.history is not None:
#    1214     raise Exception('Prophet object can only be fit once. '
#    1215                     'Instantiate a new object.')
# -> 1217 model_inputs = self.preprocess(df, **kwargs)
#    1218 initial_params = self.calculate_initial_params(model_inputs.K)
#    1220 dat = dataclasses.asdict(model_inputs)
#
# File ~\Anaconda3\Lib\site-packages\prophet\forecaster.py:1135, in Prophet.preprocess(self, df, **kwargs)
#    1132     raise ValueError('Dataframe has less than 2 non-NaN rows.')
# ...

# %%
 # Create a future dataframe to hold predictions
# Make the prediction go out as far as 2000 hours (approx 80 days)
future_mercado_trends = model_mercado_trends.make_future_dataframe(periods=2000, freq='H')

# View the last five rows of the future_mercado_trends DataFrame
future_mercado_trends.tail()
# Out:
#                              ds
# 39101 2020-11-29 23:00:00-05:00
# 39102 2020-11-30 00:00:00-05:00
# 39103 2020-11-30 01:00:00-05:00
# 39104 2020-11-30 02:00:00-05:00
# 39105 2020-11-30 03:00:00-05:00

# %%
# Make the predictions for the trend data using the future_mercado_trends DataFrame
forecast_mercado_trends = model_mercado_trends.predict(future_mercado_trends)

# Display the first five rows of the forecast_mercado_trends DataFrame
forecast_mercado_trends.head()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[133], line 2
#       1 # Make the predictions for the trend data using the future_mercado_trends DataFrame
# ----> 2 forecast_mercado_trends = model_mercado_trends.predict(future_mercado_trends)
#       4 # Display the first five rows of the forecast_mercado_trends DataFrame
#       5 forecast_mercado_trends.head()
#
# File ~\Anaconda3\Lib\site-packages\prophet\forecaster.py:1263, in Prophet.predict(self, df, vectorized)
#    1247 """Predict using the prophet model.
#    1248
#    1249 Parameters
#    (...)
#    1260 A pd.DataFrame with the forecast components.
#    1261 """
#    1262 if self.history is None:
# -> 1263     raise Exception('Model has not been fit.')
#    1265 if df is None:
#    1266     df = self.history.copy()
#
# Exception: Model has not been fit.

# %%
# Plot the Prophet predictions for the Mercado trends data
model_mercado_trends.plot(forecast_mercado_trends)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 2
#       1 # Plot the Prophet predictions for the Mercado trends data
# ----> 2 model_mercado_trends.plot(forecast_mercado_trends)
#
# NameError: name 'forecast_mercado_trends' is not defined

# %%
# Set the index in the forecast_mercado_trends DataFrame to the ds datetime column
forecast_mercado_trends = forcast_mercado_trends.set_index('ds')

# View the only the yhat,yhat_lower and yhat_upper columns from the DataFrame
forecast_mercado_trends[['yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 2
#       1 # Set the index in the forecast_mercado_trends DataFrame to the ds datetime column
# ----> 2 forecast_mercado_trends = forcast_mercado_trends.set_index('ds')
#       4 # View the only the yhat,yhat_lower and yhat_upper columns from the DataFrame
#       5 forecast_mercado_trends[['yhat', 'yhat_lower', 'yhat_upper']].head()
#
# NameError: name 'forcast_mercado_trends' is not defined

# %%
# Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# From the forecast_mercado_trends DataFrame, use hvPlot to visualize
#  the yhat, yhat_lower, and yhat_upper columns over the last 2000 hours 
model_mercado_trends.plot(forecast_mercado_trends)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ---------------------------------------------------------------------------
# ...

# %%
# Reset the index in the forecast_mercado_trends DataFrame
forecast_mercado_trends = forecast_mercado_trends = forcast_mercado_trends.reset_index('ds')

# Use the plot_components function to visualize the forecast results 
# for the forecast_canada DataFrame 
figures_mercado_trends[['yhat', 'yhat_lower', 'yhat_upper']].iloc[-2000:,:].hvplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 2
#       1 # Reset the index in the forecast_mercado_trends DataFrame
# ----> 2 forecast_mercado_trends = forecast_mercado_trends = forcast_mercado_trends.reset_index('ds')
#       4 # Use the plot_components function to visualize the forecast results
#       5 # for the forecast_canada DataFrame
#       6 figures_mercado_trends[['yhat', 'yhat_lower', 'yhat_upper']].iloc[-2000:,:].hvplot()
#
# NameError: name 'forcast_mercado_trends' is not defined
